# %%
from loguru import logger
import io3d
import io3d.datasets
import sed3
import numpy as np
import matplotlib.pyplot as plt
logger.enable("io3d")
logger.disable("io3d")
import matplotlib.pyplot as plt
from pathlib import Path

import sys
import os
print(sys.version_info)
print(sys.executable)
print(os.getcwd())
# Out:
# sys.version_info(major=3, minor=8, micro=6, releaselevel='final', serial=0)
# /home/mjirik/.conda/envs/ml/bin/python
# /home/mjirik/projects/lisa/devel

# %%
experiment_label = "rightkidney_slides"
organ_label = "rightkidney"

# %%
datap1 = io3d.datasets.read_dataset("3Dircadb1", "data3d", 1)
# datap1 = io3d.datasets.read_dataset("sliver07", "data3d", 1)
data3d = datap1["data3d"]
sed3.show_slices(data3d, shape=[2,3])
plt.figure()

# %%
datap_mask = io3d.datasets.read_dataset("3Dircadb1", organ_label, 1)
data3d_mask = datap_mask["data3d"]
sed3.show_slices(data3d_mask, shape=[2,3])
# plt.figure()

# %% [markdown]
# ## windowing

# %%
from typing import Optional
from numbers import Number

def window(
        data3d:np.ndarray,
        vmin:Optional[Number]=None,
        vmax:Optional[Number]=None,
        center:Optional[Number]=None,
        width:Optional[Number]=None,
        vmin_out:Optional[Number]=0,
        vmax_out:Optional[Number]=255,
        dtype=np.uint8):
    """
    Rescale input ndarray and trim the outlayers.

    :param data3d: ndarray with numbers
    :param vmin: minimal input value. Skipped if center and width is given.
    :param vmax: maximal input value. Skipped if center and width is given.
    :param center: Window center
    :param width: Window width
    :param vmin_out: Output mapping minimal value
    :param vmax_out: Output mapping maximal value
    :param dtype: Output dtype
    :return:
    """
    if width and center:
        vmin = center - (width / 2.)
        vmax = center + (width / 2.)

#     logger.debug(f"vmin={vmin}, vmax={vmax}")
    k = float(vmax_out - vmin_out) / (vmax - vmin)
    q = vmax_out - k * vmax
#     logger.debug(f"k={k}, q={q}")
    data3d_out = data3d * k + q

    data3d_out[data3d_out > vmax_out] = vmax_out
    data3d_out[data3d_out < vmin_out] = vmin_out

    return data3d_out.astype(dtype)



data3dw = window(data3d, center=40, width=400)
# fix, axs = plt.subplots(1,2)
# axs[]

plt.imshow(data3d[30,:,:], cmap='gray')
plt.colorbar()


plt.figure()

plt.imshow(data3dw[30,:,:], cmap='gray')
plt.colorbar()

# %%
def create_train_data(label="train", datasets=None):
    
    imgs_train = [] 
    masks_train = []    
    if not datasets:
        datasets = {
            "3Dircadb1": {"start":1, "stop":2},
#             "sliver07": {"start":0, "stop":0}
        }
    for dataset in datasets:
        
        for i in range(
            datasets[dataset]["start"], 
            datasets[dataset]["stop"]
        ):
            print(f"{dataset} {i}")
            data3dp = io3d.datasets.read_dataset(dataset, "data3d", i)
            segm3dp = io3d.datasets.read_dataset(dataset, organ_label, i)
            if segm3dp is None:
                print(f"      Organ label '{organ_label}' does not exist. Skipping.")
                continue

            data3d = window(data3dp["data3d"], center=40, width=400, vmin_out=0, vmax_out=255, dtype=np.uint8)
            segm3d = segm3dp["data3d"]

            for j in range(0, data3d.shape[0]):
                imgs_train.append(data3d[j,:,:])
                masks_train.append(segm3d[j,:,:])
                
    imgs_train = np.array(imgs_train, dtype=np.uint8)
    masks_train = np.array(masks_train, dtype=np.uint8)
    np.save(f'imgs_{label}_{experiment_label}.npy', imgs_train)
    np.save(f'masks_{label}_{experiment_label}.npy', masks_train)
    print('Saving to .npy files done.')
    return imgs_train, masks_train

# %%
def load_train_data():
    imgs_train = np.load(f'imgs_train_{experiment_label}.npy')
    masks_train = np.load(f'masks_train_{experiment_label}.npy')
    return imgs_train, masks_train
def load_test_data():
    imgs_test = np.load(f'imgs_test_{experiment_label}.npy')
    masks_test = np.load(f'masks_test_{experiment_label}.npy')
    return imgs_test, masks_test

# %%
if True:
    create_train_data(
        "train",
        datasets={
#             "3Dircadb1": {"start":1, "stop":3},
            "3Dircadb1": {"start":1, "stop":16},
#             "sliver07": {"start":1, "stop":16}
        }
    )
    create_train_data(
        "test",
        datasets={
            "3Dircadb1": {"start":16, "stop":21},
#             "sliver07": {"start":16, "stop":20}
        }
    )
# Out:
# 3Dircadb1 1
# 3Dircadb1 2
#       Organ label 'rightkidney' does not exist. Skipping.
# 3Dircadb1 3
#       Organ label 'rightkidney' does not exist. Skipping.
# 3Dircadb1 4
#       Organ label 'rightkidney' does not exist. Skipping.
# 3Dircadb1 5
# 3Dircadb1 6
# 3Dircadb1 7
# 3Dircadb1 8
#       Organ label 'rightkidney' does not exist. Skipping.
# 3Dircadb1 9
#       Organ label 'rightkidney' does not exist. Skipping.
# 3Dircadb1 10
#       Organ label 'rightkidney' does not exist. Skipping.
# 3Dircadb1 11
# 3Dircadb1 12
#       Organ label 'rightkidney' does not exist. Skipping.
# 3Dircadb1 13
#       Organ label 'rightkidney' does not exist. Skipping.
# 3Dircadb1 14
#       Organ label 'rightkidney' does not exist. Skipping.
# 3Dircadb1 15
#       Organ label 'rightkidney' does not exist. Skipping.
# Saving to .npy files done.
# 3Dircadb1 16
#       Organ label 'rightkidney' does not exist. Skipping.
# 3Dircadb1 17
#       Organ label 'rightkidney' does not exist. Skipping.
# 3Dircadb1 18
#       Organ label 'rightkidney' does not exist. Skipping.
# 3Dircadb1 19
#       Organ label 'rightkidney' does not exist. Skipping.
# 3Dircadb1 20
# Saving to .npy files done.

# %% [markdown]
# # CNN

# %% [markdown]
# '''
# conda install -c conda-forge keras-applications
# '''

# %%
from __future__ import print_function

import tensorflow as tf
import os
from skimage.transform import resize
from skimage.io import imsave
import numpy as np
from skimage.segmentation import mark_boundaries
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, concatenate, Conv2D, MaxPooling2D, Conv2DTranspose
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import History
from skimage.exposure import rescale_intensity
from skimage import io
# from data import load_train_data, load_test_data
from sklearn.utils import class_weight

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
data_oh = tf.one_hot(datap_mask['data3d'], 2)
print(data_oh.shape)
# print(data_oh)
sed3.show_slices(data_oh.numpy()[:,:,:,0].squeeze(), shape=[2,3])
# Out:
# (129, 512, 512, 2)

# %%
K.set_image_data_format('channels_last')  # TF dimension ordering in this code

img_rows = int(512/2)
img_cols = int(512/2)
smooth = 1.
#We divide here the number of rows and columns by two because we undersample our data (We take one pixel over two)

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)


def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

#The functions return our metric and loss

# %%
# one_weight = (1-num_of_ones)/(num_of_ones + num_of_zeros)
# zero_weight = (1-num_of_zeros)/(num_of_ones + num_of_zeros)

def weighted_binary_crossentropy(zero_weight, one_weight):

    def weighted_binary_crossentropy(y_true, y_pred):

        b_ce = K.binary_crossentropy(y_true, y_pred)

        # weighted calc
        weight_vector = y_true * one_weight + (1 - y_true) * zero_weight
        weighted_b_ce = weight_vector * b_ce

        return K.mean(weighted_b_ce)

    return weighted_binary_crossentropy

# %%
# wbc = weighted_binary_crossentropy(0.5, 0.5)
# u = wbc(np.array([1,1,0,1], dtype=np.float32).reshape(4,1,1,1), np.array([1,1,0,1], dtype=np.float32).reshape(4,1,1,1))

# %%
def get_unet(weights=None):
    if weights is None:
        weights = [0.05956, 3.11400]
        #{0: 0.5956388648542532, 1: 3.1140000760253925}
    
    inputs = Input((img_rows, img_cols, 1))
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)
#     conv10 = Conv2D(2, (1, 1), activation='softmax')(conv9)

    model = Model(inputs=[inputs], outputs=[conv10])

#     model.compile(optimizer=Adam(lr=1e-3), loss=dice_coef_loss, metrics=[dice_coef])
#     model.compile(optimizer='adam',  loss='binary_crossentropy', metrics=[dice_coef, "accuracy"])
    model.compile(optimizer='adam',  loss=weighted_binary_crossentropy(weights[0], weights[1]), metrics=[dice_coef, "accuracy"])
    #model.compile(optimizer='adam',  loss=weighted_binary_crossentropy(weights[0], weights[1]), metrics=[dice_coef, "accuracy"])  # categorical crossentropy (weighted)
   

    return model

#The different layers in our neural network model (including convolutions, maxpooling and upsampling)

# %%
def preprocess(imgs, is_mask=False):
    imgs_p = np.ndarray((imgs.shape[0], img_rows, img_cols), dtype=np.uint8)
    for i in range(imgs.shape[0]):
        imgs_p[i] = resize(imgs[i], (img_cols, img_rows), preserve_range=True)

    imgs_p = imgs_p[..., np.newaxis]
    if is_mask:
        imgs_p = (imgs_p > 0).astype('float32')
        
    else:
        imgs_p = imgs_p.astype('float32')
    return imgs_p

#We adapt here our dataset samples dimension so that we can feed it to our network

# %%
def save_segmentations(imgs_test, imgs_mask_test, pred_dir='preds'):
    
    if not os.path.exists(pred_dir):
        os.mkdir(pred_dir)

    for k in range(len(imgs_mask_test)):
        a=rescale_intensity(imgs_test[k][:,:,0],out_range=(-1,1))
        b=(imgs_mask_test[k][:,:,0] > 0.5).astype('uint8')
        io.imsave(os.path.join(pred_dir, f'{k:05}_pred.png'),mark_boundaries(a,b))

# %%
def train_and_predict(continue_training=False, epochs=50):
# if True:
    print('-'*30)
    print('Loading and preprocessing train data...')
    print('-'*30)
    imgs_train, imgs_mask_train = load_train_data()

    imgs_train = preprocess(imgs_train)
    imgs_mask_train = preprocess(imgs_mask_train, is_mask=True)
    
    # TODO remove - using small part of dataset
#     imgs_train = imgs_train[50:65]
#     imgs_mask_train = imgs_mask_train[50:65]

#     imgs_train = imgs_train.astype('float32')
    mean = np.mean(imgs_train)  # mean for data centering
    std = np.std(imgs_train)  # std for data normalization

    imgs_train -= mean
    imgs_train /= std
    #Normalization of the train set

#     imgs_mask_train = (imgs_mask_train > 0).astype('float32')
    
    y_train = imgs_mask_train
    # Calculate the weights for each class so that we can balance the data
    cl_weights = class_weight.compute_class_weight(
        'balanced',
        np.unique(y_train.flatten()),
        y_train.flatten()
    )
    print(f"weights={cl_weights}")
    cl_weights_dct = dict(enumerate(cl_weights))

    print('-'*30)
    print('Creating and compiling model...')
    print('-'*30)
    model = get_unet(cl_weights)
    if continue_training:
        model.load_weights(f'weights_{experiment_label}.h5')
    model_checkpoint = ModelCheckpoint(f'weights_{experiment_label}.h5', monitor='val_loss', save_best_only=True)
    #Saving the weights and the loss of the best predictions we obtained
    



    print('-'*30)
    print('Fitting model...')
    print('-'*30)
    history=model.fit(
        imgs_train, imgs_mask_train, batch_size=10, epochs=epochs, verbose=1, shuffle=True,
        validation_split=0.2,
        callbacks=[
            model_checkpoint,
            tf.keras.callbacks.TensorBoard(log_dir='./logs')
        ],
#                 class_weight=weights_dct # tohle nefunguje pro 4d data
                     )
    predict_test_data(mean, std)
    return history

def predict_test_data(mean, std):
    print('-'*30)
    print('Loading and preprocessing test data...')
    print('-'*30)
    imgs_test, imgs_maskt = load_test_data()
    imgs_test = preprocess(imgs_test)
    imgs_maskt = preprocess(imgs_maskt, is_mask=True)
    
    
    # TODO remove this limit
#     imgs_test = imgs_test[50:65]
#     imgs_maskt = imgs_maskt[50:65]
    

    imgs_test = imgs_test.astype('float32')
    imgs_test -= mean
    imgs_test /= std
    #Normalization of the test set
    
    # TODO remove this part
    # going to test on train set
#     imgs_test = imgs_train
#     imgs_maskt = imgs_mask_train



    print('-'*30)
    print('Loading saved weights...')
    print('-'*30)
    model.load_weights(f'weights_{experiment_label}.h5')

    print('-'*30)
    print('Predicting masks on test data...')
    print('-'*30)
    imgs_mask_test = model.predict(imgs_test, verbose=1)
    np.save('imgs_mask_test.npy', imgs_mask_test)
    print('-' * 30)
    print('Saving predicted masks to files...')
    print('-' * 30)
    pred_dir = f"preds/{experiment_label}"
    Path(pred_dir).mkdir(parents=True, exist_ok=True)
    #Saving our predictions in the directory 'preds'
    save_segmentations(imgs_test, imgs_mask_test, pred_dir=pred_dir)
    
    plt.plot(history.history['dice_coef'])
    plt.plot(history.history['val_dice_coef'])
    plt.title('Model dice coeff')
    plt.ylabel('Dice coeff')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
    plt.show()
    #plotting our dice coeff results in function of the number of epochs
    
#     return imgs_train, imgs_mask_train

# %%
f"__{10:04}.png"
# Out:
# '__0010.png'

# %%
# weights_dct

# %%
history = train_and_predict()
# history = train_and_predict(continue_training=True, epochs=10)
# Out:
# ------------------------------
# Loading and preprocessing train data...
# ------------------------------
# /home/mjirik/.conda/envs/ml/lib/python3.8/site-packages/sklearn/utils/validation.py:67: FutureWarning: Pass classes=[0. 1.], y=[0. 0. 0. ... 0. 0. 0.] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# weights=[ 0.50289147 86.96114788]
# ------------------------------
# Creating and compiling model...
# ------------------------------
# ------------------------------
# Fitting model...
# ------------------------------
# Epoch 1/50
#  1/55 [..............................] - ETA: 0s - loss: 0.7122 - dice_coef: 0.0095 - accuracy: 0.9843WARNING:tensorflow:From /home/mjirik/.conda/envs/ml/lib/python3.8/site-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# 55/55 [==============================] - 466s 8s/step - loss: 0.4525 - dice_coef: 0.0335 - accuracy: 0.7077 - val_loss: 0.2639 - val_dice_coef: 0.0450 - val_accuracy: 0.7589
# Epoch 2/50
# 55/55 [==============================] - 466s 8s/step - loss: 0.3627 - dice_coef: 0.0395 - accuracy: 0.7110 - val_loss: 0.2546 - val_dice_coef: 0.0496 - val_accuracy: 0.7799
# Epoch 3/50
# 55/55 [==============================] - 466s 8s/step - loss: 0.2945 - dice_coef: 0.0441 - accuracy: 0.7336 - val_loss: 0.2274 - val_dice_coef: 0.0552 - val_accuracy: 0.7940
# Epoch 4/50
# 55/55 [==============================] - 466s 8s/step - loss: 0.2324 - dice_coef: 0.0873 - accuracy: 0.8397 - val_loss: 0.2536 - val_dice_coef: 0.0477 - val_accuracy: 0.7533
# Epoch 5/50
# 55/55 [==============================] - 465s 8s/step - loss: 0.2689 - dice_coef: 0.0506 - accuracy: 0.7680 - val_loss: 0.1823 - val_dice_coef: 0.0743 - val_accuracy: 0.8680
# Epoch 6/50
# 55/55 [==============================] - 465s 8s/step - loss: 0.2100 - dice_coef: 0.0789 - accuracy: 0.8801 - val_loss: 0.1421 - val_dice_coef: 0.1049 - val_accuracy: 0.9112
# Epoch 7/50
# 55/55 [==============================] - 465s 8s/step - loss: 0.1829 - dice_coef: 0.0944 - accuracy: 0.9062 - val_loss: 0.1177 - val_dice_coef: 0.1253 - val_accuracy: 0.9534
# Epoch 8/50
# 55/55 [==============================] - 465s 8s/step - loss: 0.2025 - dice_coef: 0.0893 - accuracy: 0.8853 - val_loss: 0.1299 - val_dice_coef: 0.1330 - val_accuracy: 0.9597
# Epoch 9/50
# 55/55 [==============================] - 465s 8s/step - loss: 0.2246 - dice_coef: 0.0779 - accuracy: 0.8574 - val_loss: 0.1736 - val_dice_coef: 0.0921 - val_accuracy: 0.9023
# Epoch 10/50
# 55/55 [==============================] - 465s 8s/step - loss: 0.1987 - dice_coef: 0.0881 - accuracy: 0.8905 - val_loss: 0.1145 - val_dice_coef: 0.1327 - val_accuracy: 0.9513
# Epoch 11/50
# 55/55 [==============================] - 464s 8s/step - loss: 0.1774 - dice_coef: 0.1046 - accuracy: 0.9117 - val_loss: 0.1580 - val_dice_coef: 0.0988 - val_accuracy: 0.8880
# Epoch 12/50
# 55/55 [==============================] - 464s 8s/step - loss: 0.1792 - dice_coef: 0.1102 - accuracy: 0.9149 - val_loss: 0.1175 - val_dice_coef: 0.1244 - val_accuracy: 0.9437
# Epoch 13/50
# 55/55 [==============================] - 465s 8s/step - loss: 0.1644 - dice_coef: 0.1124 - accuracy: 0.9185 - val_loss: 0.1054 - val_dice_coef: 0.1337 - val_accuracy: 0.9521
# Epoch 14/50
# 55/55 [==============================] - 464s 8s/step - loss: 0.1671 - dice_coef: 0.1097 - accuracy: 0.9152 - val_loss: 0.1511 - val_dice_coef: 0.1002 - val_accuracy: 0.8923
# Epoch 15/50
# 55/55 [==============================] - 465s 8s/step - loss: 0.1567 - dice_coef: 0.1119 - accuracy: 0.9185 - val_loss: 0.1133 - val_dice_coef: 0.1293 - val_accuracy: 0.9485
# Epoch 16/50
# 55/55 [==============================] - 464s 8s/step - loss: 0.1553 - dice_coef: 0.1170 - accuracy: 0.9187 - val_loss: 0.1071 - val_dice_coef: 0.1261 - val_accuracy: 0.9441
# Epoch 17/50
# 55/55 [==============================] - 465s 8s/step - loss: 0.1645 - dice_coef: 0.1148 - accuracy: 0.9163 - val_loss: 0.0962 - val_dice_coef: 0.1305 - val_accuracy: 0.9508
# Epoch 18/50
# 55/55 [==============================] - 464s 8s/step - loss: 0.1610 - dice_coef: 0.1183 - accuracy: 0.9141 - val_loss: 0.1278 - val_dice_coef: 0.1094 - val_accuracy: 0.9314
# Epoch 19/50
# 55/55 [==============================] - 464s 8s/step - loss: 0.1387 - dice_coef: 0.1271 - accuracy: 0.9309 - val_loss: 0.0911 - val_dice_coef: 0.1327 - val_accuracy: 0.9526
# Epoch 20/50
# 55/55 [==============================] - 465s 8s/step - loss: 0.1368 - dice_coef: 0.1265 - accuracy: 0.9281 - val_loss: 0.0832 - val_dice_coef: 0.1497 - val_accuracy: 0.9626
# Epoch 21/50
# 55/55 [==============================] - 464s 8s/step - loss: 0.1545 - dice_coef: 0.1403 - accuracy: 0.9318 - val_loss: 0.1768 - val_dice_coef: 0.0618 - val_accuracy: 0.8772
# Epoch 22/50
# 55/55 [==============================] - 465s 8s/step - loss: 0.1490 - dice_coef: 0.1185 - accuracy: 0.9261 - val_loss: 0.0808 - val_dice_coef: 0.1458 - val_accuracy: 0.9603
# Epoch 23/50
# 55/55 [==============================] - 465s 8s/step - loss: 0.1265 - dice_coef: 0.1334 - accuracy: 0.9366 - val_loss: 0.0860 - val_dice_coef: 0.1533 - val_accuracy: 0.9645
# Epoch 24/50
# 55/55 [==============================] - 464s 8s/step - loss: 0.1277 - dice_coef: 0.1358 - accuracy: 0.9381 - val_loss: 0.1004 - val_dice_coef: 0.1262 - val_accuracy: 0.9424
# Epoch 25/50
# 55/55 [==============================] - 465s 8s/step - loss: 0.1262 - dice_coef: 0.1413 - accuracy: 0.9396 - val_loss: 0.0805 - val_dice_coef: 0.1427 - val_accuracy: 0.9605
# Epoch 26/50
# 55/55 [==============================] - 465s 8s/step - loss: 0.1104 - dice_coef: 0.1524 - accuracy: 0.9477 - val_loss: 0.0764 - val_dice_coef: 0.1450 - val_accuracy: 0.9602
# Epoch 27/50
# 55/55 [==============================] - 464s 8s/step - loss: 0.1263 - dice_coef: 0.1447 - accuracy: 0.9411 - val_loss: 0.0823 - val_dice_coef: 0.1430 - val_accuracy: 0.9600
# Epoch 28/50
# 55/55 [==============================] - 465s 8s/step - loss: 0.1210 - dice_coef: 0.1401 - accuracy: 0.9419 - val_loss: 0.0825 - val_dice_coef: 0.1591 - val_accuracy: 0.9691
# Epoch 29/50
# 55/55 [==============================] - 465s 8s/step - loss: 0.1085 - dice_coef: 0.1580 - accuracy: 0.9500 - val_loss: 0.0748 - val_dice_coef: 0.1480 - val_accuracy: 0.9618
# Epoch 30/50
# 55/55 [==============================] - 464s 8s/step - loss: 0.1123 - dice_coef: 0.1550 - accuracy: 0.9484 - val_loss: 0.0747 - val_dice_coef: 0.1452 - val_accuracy: 0.9629
# Epoch 31/50
# 55/55 [==============================] - 464s 8s/step - loss: 0.1134 - dice_coef: 0.1597 - accuracy: 0.9478 - val_loss: 0.0821 - val_dice_coef: 0.1415 - val_accuracy: 0.9629
# Epoch 32/50
# 55/55 [==============================] - 467s 8s/step - loss: 0.1558 - dice_coef: 0.1248 - accuracy: 0.9118 - val_loss: 0.1395 - val_dice_coef: 0.0947 - val_accuracy: 0.8975
# Epoch 33/50
# 55/55 [==============================] - 471s 9s/step - loss: 0.1468 - dice_coef: 0.1178 - accuracy: 0.9229 - val_loss: 0.0981 - val_dice_coef: 0.1314 - val_accuracy: 0.9531
# Epoch 34/50
# 55/55 [==============================] - 469s 9s/step - loss: 0.1187 - dice_coef: 0.1522 - accuracy: 0.9494 - val_loss: 0.0731 - val_dice_coef: 0.1544 - val_accuracy: 0.9679
# Epoch 35/50
# 55/55 [==============================] - 466s 8s/step - loss: 0.1096 - dice_coef: 0.1683 - accuracy: 0.9523 - val_loss: 0.0727 - val_dice_coef: 0.1713 - val_accuracy: 0.9739
# Epoch 36/50
# 55/55 [==============================] - 466s 8s/step - loss: 0.1130 - dice_coef: 0.1632 - accuracy: 0.9498 - val_loss: 0.0679 - val_dice_coef: 0.1632 - val_accuracy: 0.9706
# Epoch 37/50
# 55/55 [==============================] - 465s 8s/step - loss: 0.1059 - dice_coef: 0.1675 - accuracy: 0.9546 - val_loss: 0.1056 - val_dice_coef: 0.1289 - val_accuracy: 0.9409
# Epoch 38/50
# 55/55 [==============================] - 465s 8s/step - loss: 0.1103 - dice_coef: 0.1592 - accuracy: 0.9491 - val_loss: 0.0664 - val_dice_coef: 0.1601 - val_accuracy: 0.9697
# Epoch 39/50
# 55/55 [==============================] - 464s 8s/step - loss: 0.1021 - dice_coef: 0.1679 - accuracy: 0.9554 - val_loss: 0.0966 - val_dice_coef: 0.1262 - val_accuracy: 0.9483
# Epoch 40/50
# 55/55 [==============================] - 464s 8s/step - loss: 0.1061 - dice_coef: 0.1654 - accuracy: 0.9534 - val_loss: 0.0690 - val_dice_coef: 0.1586 - val_accuracy: 0.9686
# Epoch 41/50
# 55/55 [==============================] - 464s 8s/step - loss: 0.1014 - dice_coef: 0.1689 - accuracy: 0.9560 - val_loss: 0.0702 - val_dice_coef: 0.1486 - val_accuracy: 0.9635
# Epoch 42/50
# 55/55 [==============================] - 465s 8s/step - loss: 0.0960 - dice_coef: 0.1820 - accuracy: 0.9587 - val_loss: 0.0613 - val_dice_coef: 0.1641 - val_accuracy: 0.9715
# Epoch 43/50
# 55/55 [==============================] - 466s 8s/step - loss: 0.0947 - dice_coef: 0.1825 - accuracy: 0.9598 - val_loss: 0.0696 - val_dice_coef: 0.1771 - val_accuracy: 0.9760
# Epoch 44/50
# 55/55 [==============================] - 465s 8s/step - loss: 0.0990 - dice_coef: 0.1786 - accuracy: 0.9569 - val_loss: 0.0625 - val_dice_coef: 0.1643 - val_accuracy: 0.9713
# Epoch 45/50
# 55/55 [==============================] - 465s 8s/step - loss: 0.0942 - dice_coef: 0.1801 - accuracy: 0.9596 - val_loss: 0.0628 - val_dice_coef: 0.1632 - val_accuracy: 0.9699
# Epoch 46/50
# 55/55 [==============================] - 465s 8s/step - loss: 0.0908 - dice_coef: 0.1899 - accuracy: 0.9600 - val_loss: 0.0650 - val_dice_coef: 0.1728 - val_accuracy: 0.9753
# Epoch 47/50
# 55/55 [==============================] - 466s 8s/step - loss: 0.1060 - dice_coef: 0.1728 - accuracy: 0.9522 - val_loss: 0.0622 - val_dice_coef: 0.1751 - val_accuracy: 0.9746
# Epoch 48/50
# 55/55 [==============================] - 466s 8s/step - loss: 0.0904 - dice_coef: 0.1940 - accuracy: 0.9615 - val_loss: 0.0587 - val_dice_coef: 0.1700 - val_accuracy: 0.9730
# Epoch 49/50
# 55/55 [==============================] - 465s 8s/step - loss: 0.0931 - dice_coef: 0.1860 - accuracy: 0.9586 - val_loss: 0.0641 - val_dice_coef: 0.1798 - val_accuracy: 0.9766
# Epoch 50/50
# 55/55 [==============================] - 465s 8s/step - loss: 0.0933 - dice_coef: 0.1879 - accuracy: 0.9612 - val_loss: 0.0635 - val_dice_coef: 0.1623 - val_accuracy: 0.9704
# ------------------------------
# Loading and preprocessing test data...
# ------------------------------
# ------------------------------
# Loading saved weights...
# ------------------------------
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-69-3ec1cdfccbee> in <module>
# ----> 1 history = train_and_predict()
#       2 # history = train_and_predict(continue_training=True, epochs=10)
#
# <ipython-input-63-176b0fee5e69> in train_and_predict(continue_training, epochs)
#      84     print('Loading saved weights...')
#      85     print('-'*30)
# ---> 86     model.load_weights('weights.h5')
#      87
#      88     print('-'*30)
#
# ~/.conda/envs/ml/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in load_weights(self, filepath, by_name, skip_mismatch, options)
#    2202           'first, then load the weights.')
#    2203     self._assert_weights_created()
# -> 2204     with h5py.File(filepath, 'r') as f:
#    2205       if 'layer_names' not in f.attrs and 'model_weights' in f:
#    2206         f = f['model_weights']
#
# ~/.conda/envs/ml/lib/python3.8/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     404             with phil:
#     405                 fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0, **kwds)
# --> 406                 fid = make_fid(name, mode, userblock_size,
#     407                                fapl, fcpl=make_fcpl(track_order=track_order),
#     408                                swmr=swmr)
#
# ~/.conda/envs/ml/lib/python3.8/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     171         if swmr and swmr_support:
#     172             flags |= h5f.ACC_SWMR_READ
# --> 173         fid = h5f.open(name, flags, fapl=fapl)
#     174     elif mode == 'r+':
#     175         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = 'weights.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
imgs_train, imgs_mask_train = load_test_data()

imgs_train = preprocess(imgs_train)
imgs_mask_train = preprocess(imgs_mask_train)

imgs_train = imgs_train.astype('float32')
mean = np.mean(imgs_train)  # mean for data centering
std = np.std(imgs_train)  # std for data normalization
predict_test_data(mean, std)
# Out:
# ------------------------------
# Loading and preprocessing test data...
# ------------------------------
# ------------------------------
# Loading saved weights...
# ------------------------------
# ------------------------------
# Predicting masks on test data...
# ------------------------------
# 8/8 [==============================] - 42s 5s/step
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [-1.0, 1.0]. Convert image to uint8 prior to saving to suppress this warning.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-88-7f8fdc1e274c> in <module>
#       7 mean = np.mean(imgs_train)  # mean for data centering
#       8 std = np.std(imgs_train)  # std for data normalization
# ----> 9 predict_test_data(mean, std)
#
# <ipython-input-86-99946cf8a6cc> in predict_test_data(mean, std)
#     104     save_segmentations(imgs_test, imgs_mask_test, pred_dir=pred_dir)
#     105
# --> 106     plt.plot(history.history['dice_coef'])
#     107     plt.plot(history.history['val_dice_coef'])
#     108     plt.title('Model dice coeff')
#
# NameError: name 'history' is not defined

# %% [markdown]
# # Try one image

# %%
imgs_train, imgs_mask_train = load_test_data()

imgs_train = preprocess(imgs_train)
imgs_mask_train = preprocess(imgs_mask_train)

imgs_train = imgs_train.astype('float32')
mean = np.mean(imgs_train)  # mean for data centering
std = np.std(imgs_train)  # std for data normalization

imgs_train -= mean
imgs_train /= std
#Normalization of the train set

imgs_mask_train = imgs_mask_train.astype('float32')

print(f"Number of frames={imgs_train.shape[0]}")
# Out:
# Number of frames=225

# %%
model = get_unet()

model.load_weights(f'weights_{experiment_label}.h5')

print('-'*30)
print('Predicting masks on test data...')
print('-'*30)
imgs_mask_train_pred = model.predict(imgs_train, verbose=1)
# Out:
# ------------------------------
# Predicting masks on test data...
# ------------------------------
# 8/8 [==============================] - 42s 5s/step

# %%
import scipy.stats

scipy.stats.describe(imgs_mask_train_pred.flatten())
# Out:
# DescribeResult(nobs=14745600, minmax=(3.2140388e-11, 0.999836), mean=0.05225081, variance=0.032979712, skewness=4.078247547149658, kurtosis=15.931064869364473)

# %%
i = 100

# %%
plt.imshow(imgs_train[i,:,:], cmap='gray')
plt.colorbar()

# %%
plt.imshow(imgs_mask_train_pred[i,:,:], cmap='gray')
plt.colorbar()

# %%
plt.imshow(imgs_mask_train[i,:,:], cmap='gray')
plt.colorbar()

# %%
tf.keras.losses.binary_crossentropy(imgs_mask_train[i,:,:].flatten(), imgs_mask_train_pred[i,:,:].flatten())

# %%
tf.keras.losses.binary_crossentropy(imgs_mask_train.flatten(), imgs_mask_train_pred.flatten())

# %%
save_segmentations(imgs_train, imgs_mask_train_pred, f"preds_test/{experiment_label}")

# %%
y_train=(imgs_mask_train > 0).astype(np.float32)
weights = class_weight.compute_class_weight('balanced', np.unique(y_train.flatten()), y_train.flatten())
# y_train.shape
# imgs_train.shape
# y_train.dtype
# print(np.unique(imgs_mask_train > 0))

# plt.imshow(imgs_mask_train[150,:,:] > 0, interpolation='None')
print(weights)
